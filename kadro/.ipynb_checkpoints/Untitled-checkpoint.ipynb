# %%
import pandas as pd
import os

# %%
df=pd.read_csv("otf.csv")

# %%
df
# Out:
#                    Zaman damgası               Ad-Soyad  \
# 0   2026/03/05 11:26:52 ÖÖ GMT+3         SERCAN BAŞARAN
# 1   2026/03/05 11:29:14 ÖÖ GMT+3           Levent YÜCEL
# 2   2026/03/05 11:30:48 ÖÖ GMT+3         Gülper AKPINAR
# 3   2026/03/05 11:30:58 ÖÖ GMT+3  Nurcan Ada Çetinkaya
# 4   2026/03/05 11:31:17 ÖÖ GMT+3        Abdulhalik AKER
# ..                           ...                    ...
# 92   2026/03/15 2:35:01 ÖS GMT+3            FATMA NÜKTE
# 93   2026/03/15 5:01:23 ÖS GMT+3            Emine Nigar
# 94   2026/03/15 6:26:20 ÖS GMT+3            Fadime YAŞA
# 95   2026/03/15 7:05:05 ÖS GMT+3          Gülendam Ünal
# 96  2026/03/16 11:11:36 ÖÖ GMT+3       Cennet Uzunoğlu
#
#                       Branş       Şehir  \
# 0   Türk Dili ve Edebiyatı    Nevşehir
# 1           Sınıf Öğretmeni       Hatay
# 2           Sınıf Öğretmeni       Adana
# 3                 İngilizce       Adana
# 4    Türk Dili ve Edebiyatı  Diyarbakır
# ..                      ...         ...
# 92                İNGİLİZCE       KONYA
# 93                İngilizce      Ankara
# 94          Sınıf Öğretmeni     Manisa
# 95                   Türkçe       Bursa
# 96  Türk Dili ve Edebiyatı      Ankara
#
#    Kendinizi tanıtınız (En fazla 200 kelime) \nTanıtım içi  \
# 0   Çok sevdiğim öğretmenlik mesleğine 2008 yılınd...
# 1   Levent Yücel, 29 yıllık deneyime sahip sınıf ö...
# 2   Lisans eğitimimi tamamladıktan sonra eğitim al...
# 3   1983 Hatay doğumluyum. 20 yıllık İngilizce öğr...
# 4   1989 Diyarbakır doğumluyum. Diyarbakır Kayapın...
# ..                                                ...
# 92  Ben Fatma Nükte. Öğrenmeyi ve öğretmeyi seven ...
# 93  Merhaba,ben Emine Nigar.Gazi Üniversitesi İngi...
# 94  23.12.2005 tarihinde  göreve başladım.Şu anda ...
# 95  Gazi Ünv. mezunu,15 yıllık Türkçe öğretmeniyim...
# 96                                                NaN
#
#                             Fotoğrafınızı yükleyiniz.
# 0                                                 NaN
# 1                                                 NaN
# 2   https://drive.google.com/u/0/open?usp=forms_we...
# 3   https://drive.google.com/u/0/open?usp=forms_we...
# 4   https://drive.google.com/u/0/open?usp=forms_we...
# ..                                                ...
# 92  https://drive.google.com/u/0/open?usp=forms_we...
# 93  https://drive.google.com/u/0/open?usp=forms_we...
# 94  https://drive.google.com/u/0/open?usp=forms_we...
# 95  https://drive.google.com/u/0/open?usp=forms_we...
# 96  https://drive.google.com/u/0/open?usp=forms_we...
#
# [97 rows x 6 columns]

# %%
df.to_excel("ok.xlsx")

# %%
df.columns
# Out:
# Index(['Zaman damgası', 'Ad-Soyad', 'Branş', 'Şehir',
#        'Kendinizi tanıtınız (En fazla 200 kelime) \nTanıtım içi',
#        'Fotoğrafınızı yükleyiniz.'],
#       dtype='object')

# %%
for i in df['City/County  (Şehir)'].unique():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City/County  (Şehir)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for i in df['City/County  (Şehir)'].unique():
#       2     print(i)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: 'City/County  (Şehir)'

# %%
def find_the_way(path,file_format):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                files_add.append(os.path.join(r, file))  
    return files_add
files_add=find_the_way('./','.jpg')

# %%
files_add
# Out:
# ['./img\\aacetinkaya.jpg',
#  './img\\aaker.jpg',
#  './img\\aari.jpg',
#  './img\\abozat.jpg',
#  './img\\adurur.jpg',
#  './img\\afuttu.jpg',
#  './img\\agokmen.jpg',
#  './img\\auysal.jpg',
#  './img\\ayalcinkaya.jpg',
#  './img\\azoba.jpg',
#  './img\\berkmen.jpg',
#  './img\\bodemir.jpg',
#  './img\\btorgul.jpg',
#  './img\\csakir.jpg',
#  './img\\cuzunoglu.jpg',
#  './img\\cyalcin.jpg',
#  './img\\dbsekin.jpg',
#  './img\\dry - e- twinning.jpg',
#  './img\\dtop.jpg',
#  './img\\ederoglu.jpg',
#  './img\\edogan.jpg',
#  './img\\eergin.jpg',
#  './img\\eerol.jpg',
#  './img\\eertas.jpg',
#  './img\\enigar.jpg',
#  './img\\evrendogan.jpg',
#  './img\\eyardimci.jpg',
#  './img\\febilir.jpg',
#  './img\\ffici.jpg',
#  './img\\fnukte.jpg',
#  './img\\fyasa.jpg',
#  './img\\gakpinar.jpg',
#  './img\\gunal.jpg',
#  './img\\gyalman.jpg',
#  './img\\hersin.jpg',
#  './img\\hpektas.jpg',
#  './img\\hyanci.jpg',
#  './img\\hyildiz.jpg',
#  './img\\ierk.jpg',
#  './img\\isanli.jpg',
#  './img\\lmeshur.jpg',
#  './img\\matli.jpg',
#  './img\\mcoskun.jpg',
#  './img\\meavci.jpg',
#  './img\\mkutlu.jpg',
#  './img\\mnazli.jpg',
#  './img\\myesil.jpg',
#  './img\\naydin.jpg',
#  './img\\nayhan.jpg',
#  './img\\ncetin.jpg',
#  './img\\okocabiyik.jpg',
#  './img\\oyasar.jpg',
#  './img\\oyucehunkar.jpg',
#  './img\\pince.jpg',
#  './img\\sacikgoz.jpg',
#  './img\\sdemirel.jpg',
#  './img\\sgokceli.jpg',
#  './img\\ssaydemir.jpg',
#  './img\\ucanpolat.jpg',
#  './img\\uguclu.jpg',
#  './img\\uoktay.jpg',
#  './img\\ziuzun.jpg',
#  './img\\ztaltindis.jpg',
#  './img\\zyildirim.jpg',
#  './img\\zyilmaz.jpg']
